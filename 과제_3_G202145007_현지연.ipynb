# %% [markdown]
# <a href="https://colab.research.google.com/github/jiyeon1357/seq2seq/blob/main/%EA%B3%BC%EC%A0%9C_3_G202145007_%ED%98%84%EC%A7%80%EC%97%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 다음의 1과 2 중 택1하여 seq2seq 모형을 적용하여 보아라.
# 1) 주어진자료(교재내 자료 포함 등)와 하여 새로운 문장 생성 또는 덧셈, 뺄셈 문제에 적용
#
# 2) 본인관심자료를 활용하여 특정 task 수행(예. 새로운 문장생성, 문장요약 등, 이미지 요약 등등)

# %% [markdown]
# #### 1) seq2seq - 교재 자료 ( 덧셈 문제)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/My Drive/deep-learning-from-scratch-2-master")

# %%
import os
os.getcwd()
# Out:
# '/content/drive/My Drive/deep-learning-from-scratch-2-master'

# %%
import sys
sys.path.append('..')
from dataset import sequence

(x_train, t_train), (x_test, t_test) = \
    sequence.load_data('addition.txt', seed=1984)
char_to_id, id_to_char = sequence.get_vocab()

print(x_train.shape, t_train.shape)
print(x_test.shape, t_test.shape)
# (45000, 7) (45000, 5)
# (5000, 7) (5000, 5)

print(x_train[0])
print(t_train[0])
# [ 3  0  2  0  0 11  5]
# [ 6  0 11  7  5]

print(''.join([id_to_char[c] for c in x_train[0]]))
print(''.join([id_to_char[c] for c in t_train[0]]))
# 71+118
# _189
# Out:
# (45000, 7) (45000, 5)
# (5000, 7) (5000, 5)
# [ 3  0  2  0  0 11  5]
# [ 6  0 11  7  5]
# 71+118
# _189

# %%
# Encoder 클래스 코드
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel

class Encoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=False)

        self.params = self.embed.params + self.lstm.params
        self.grads = self.embed.grads + self.lstm.grads
        self.hs = None

    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.lstm.forward(xs)
        self.hs = hs
        return hs[:, -1, :]

    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.lstm.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %%
# Decoder 클래스 코드
class Decoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, xs, h):
        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        out = self.lstm.forward(out)
        score = self.affine.forward(out)
        return score

    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.lstm.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.lstm.dh
        return dh
    
    # Decoder 클래스에 문장 생성을 담당하는 generte() 메서드
    def generate(self, h, start_id, sample_size):
        sampled = []
        sample_id = start_id
        self.lstm.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1, 1))
            out = self.embed.forward(x)
            out = self.lstm.forward(out)
            score = self.affine.forward(out)

            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))

        return sampled

# %%
class Seq2seq(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = Decoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]

        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss

    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout

    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %%
# seq2seq 학습 코드
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq


# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hideen_size = 128
batch_size = 128
max_epoch = 50
max_grad = 5.0

model = Seq2seq(vocab_size, wordvec_size, hideen_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.56
# | 에폭 1 |  반복 21 / 351 | 시간 1[s] | 손실 2.53
# | 에폭 1 |  반복 41 / 351 | 시간 2[s] | 손실 2.17
# | 에폭 1 |  반복 61 / 351 | 시간 3[s] | 손실 1.96
# | 에폭 1 |  반복 81 / 351 | 시간 5[s] | 손실 1.92
# | 에폭 1 |  반복 101 / 351 | 시간 6[s] | 손실 1.87
# | 에폭 1 |  반복 121 / 351 | 시간 7[s] | 손실 1.85
# | 에폭 1 |  반복 141 / 351 | 시간 8[s] | 손실 1.83
# | 에폭 1 |  반복 161 / 351 | 시간 10[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 11[s] | 손실 1.77
# | 에폭 1 |  반복 201 / 351 | 시간 12[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 13[s] | 손실 1.76
# | 에폭 1 |  반복 241 / 351 | 시간 15[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 16[s] | 손실 1.76
# | 에폭 1 |  반복 281 / 351 | 시간 17[s] | 손실 1.75
# | 에폭 1 |  반복 301 / 351 | 시간 19[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 20[s] | 손실 1.75
# | 에폭 1 |  반복 341 / 351 | 시간 21[s] | 손실 1.74
# Q 77+85
# T 162
# ☒ 100
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 1000
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 1000
# ---
# Q 600+257
# T 857
# ☒ 1000
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1000
# ---
# Q 26+838
# T 864
# ☒ 1000
# ---
# Q 143+93
# T 236
# ☒ 100
# ---
# 검증 정확도 0.180%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.74
# | 에폭 2 |  반복 21 / 351 | 시간 1[s] | 손실 1.73
# | 에폭 2 |  반복 41 / 351 | 시간 2[s] | 손실 1.74
# | 에폭 2 |  반복 61 / 351 | 시간 3[s] | 손실 1.74
# | 에폭 2 |  반복 81 / 351 | 시간 5[s] | 손실 1.73
# | 에폭 2 |  반복 101 / 351 | 시간 6[s] | 손실 1.73
# | 에폭 2 |  반복 121 / 351 | 시간 7[s] | 손실 1.72
# | 에폭 2 |  반복 141 / 351 | 시간 8[s] | 손실 1.71
# | 에폭 2 |  반복 161 / 351 | 시간 10[s] | 손실 1.71
# | 에폭 2 |  반복 181 / 351 | 시간 11[s] | 손실 1.71
# | 에폭 2 |  반복 201 / 351 | 시간 12[s] | 손실 1.70
# | 에폭 2 |  반복 221 / 351 | 시간 14[s] | 손실 1.71
# | 에폭 2 |  반복 241 / 351 | 시간 15[s] | 손실 1.70
# | 에폭 2 |  반복 261 / 351 | 시간 16[s] | 손실 1.69
# | 에폭 2 |  반복 281 / 351 | 시간 17[s] | 손실 1.69
# | 에폭 2 |  반복 301 / 351 | 시간 19[s] | 손실 1.69
# | 에폭 2 |  반복 321 / 351 | 시간 20[s] | 손실 1.68
# | 에폭 2 |  반복 341 / 351 | 시간 21[s] | 손실 1.67
# Q 77+85
# T 162
# ☒ 994
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 700
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 400
# ---
# Q 600+257
# T 857
# ☒ 1000
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1544
# ---
# Q 26+838
# T 864
# ☒ 400
# ---
# Q 143+93
# T 236
# ☒ 400
# ---
# 검증 정확도 0.220%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.66
# | 에폭 3 |  반복 21 / 351 | 시간 1[s] | 손실 1.66
# | 에폭 3 |  반복 41 / 351 | 시간 2[s] | 손실 1.65
# | 에폭 3 |  반복 61 / 351 | 시간 3[s] | 손실 1.63
# | 에폭 3 |  반복 81 / 351 | 시간 5[s] | 손실 1.62
# | 에폭 3 |  반복 101 / 351 | 시간 6[s] | 손실 1.62
# | 에폭 3 |  반복 121 / 351 | 시간 7[s] | 손실 1.60
# | 에폭 3 |  반복 141 / 351 | 시간 9[s] | 손실 1.59
# | 에폭 3 |  반복 161 / 351 | 시간 10[s] | 손실 1.57
# | 에폭 3 |  반복 181 / 351 | 시간 11[s] | 손실 1.57
# | 에폭 3 |  반복 201 / 351 | 시간 12[s] | 손실 1.56
# | 에폭 3 |  반복 221 / 351 | 시간 14[s] | 손실 1.54
# | 에폭 3 |  반복 241 / 351 | 시간 15[s] | 손실 1.52
# | 에폭 3 |  반복 261 / 351 | 시간 16[s] | 손실 1.52
# | 에폭 3 |  반복 281 / 351 | 시간 18[s] | 손실 1.52
# | 에폭 3 |  반복 301 / 351 | 시간 19[s] | 손실 1.50
# | 에폭 3 |  반복 321 / 351 | 시간 20[s] | 손실 1.49
# | 에폭 3 |  반복 341 / 351 | 시간 22[s] | 손실 1.48
# Q 77+85
# T 162
# ☒ 108
# ---
# Q 975+164
# T 1139
# ☒ 1001
# ---
# Q 582+84
# T 666
# ☒ 648
# ---
# Q 8+155
# T 163
# ☒ 138
# ---
# Q 367+55
# T 422
# ☒ 448
# ---
# Q 600+257
# T 857
# ☒ 848
# ---
# Q 761+292
# T 1053
# ☒ 1011
# ---
# Q 830+597
# T 1427
# ☒ 1373
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 348
# ---
# 검증 정확도 0.560%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.47
# | 에폭 4 |  반복 21 / 351 | 시간 1[s] | 손실 1.46
# | 에폭 4 |  반복 41 / 351 | 시간 2[s] | 손실 1.44
# | 에폭 4 |  반복 61 / 351 | 시간 3[s] | 손실 1.43
# | 에폭 4 |  반복 81 / 351 | 시간 5[s] | 손실 1.42
# | 에폭 4 |  반복 101 / 351 | 시간 6[s] | 손실 1.41
# | 에폭 4 |  반복 121 / 351 | 시간 7[s] | 손실 1.40
# | 에폭 4 |  반복 141 / 351 | 시간 9[s] | 손실 1.40
# | 에폭 4 |  반복 161 / 351 | 시간 10[s] | 손실 1.38
# | 에폭 4 |  반복 181 / 351 | 시간 11[s] | 손실 1.38
# | 에폭 4 |  반복 201 / 351 | 시간 13[s] | 손실 1.37
# | 에폭 4 |  반복 221 / 351 | 시간 14[s] | 손실 1.35
# | 에폭 4 |  반복 241 / 351 | 시간 15[s] | 손실 1.33
# | 에폭 4 |  반복 261 / 351 | 시간 17[s] | 손실 1.33
# | 에폭 4 |  반복 281 / 351 | 시간 18[s] | 손실 1.33
# | 에폭 4 |  반복 301 / 351 | 시간 19[s] | 손실 1.32
# | 에폭 4 |  반복 321 / 351 | 시간 21[s] | 손실 1.31
# | 에폭 4 |  반복 341 / 351 | 시간 22[s] | 손실 1.30
# Q 77+85
# T 162
# ☒ 146
# ---
# Q 975+164
# T 1139
# ☒ 1189
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 432
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1002
# ---
# Q 830+597
# T 1427
# ☒ 1406
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 202
# ---
# 검증 정확도 1.060%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.28
# | 에폭 5 |  반복 21 / 351 | 시간 1[s] | 손실 1.29
# | 에폭 5 |  반복 41 / 351 | 시간 2[s] | 손실 1.28
# | 에폭 5 |  반복 61 / 351 | 시간 4[s] | 손실 1.27
# | 에폭 5 |  반복 81 / 351 | 시간 5[s] | 손실 1.27
# | 에폭 5 |  반복 101 / 351 | 시간 6[s] | 손실 1.26
# | 에폭 5 |  반복 121 / 351 | 시간 7[s] | 손실 1.26
# | 에폭 5 |  반복 141 / 351 | 시간 9[s] | 손실 1.27
# | 에폭 5 |  반복 161 / 351 | 시간 10[s] | 손실 1.26
# | 에폭 5 |  반복 181 / 351 | 시간 11[s] | 손실 1.25
# | 에폭 5 |  반복 201 / 351 | 시간 13[s] | 손실 1.23
# | 에폭 5 |  반복 221 / 351 | 시간 14[s] | 손실 1.22
# | 에폭 5 |  반복 241 / 351 | 시간 15[s] | 손실 1.21
# | 에폭 5 |  반복 261 / 351 | 시간 17[s] | 손실 1.21
# | 에폭 5 |  반복 281 / 351 | 시간 18[s] | 손실 1.21
# | 에폭 5 |  반복 301 / 351 | 시간 19[s] | 손실 1.20
# | 에폭 5 |  반복 321 / 351 | 시간 21[s] | 손실 1.19
# | 에폭 5 |  반복 341 / 351 | 시간 22[s] | 손실 1.18
# Q 77+85
# T 162
# ☒ 145
# ---
# Q 975+164
# T 1139
# ☒ 1168
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 192
# ---
# Q 367+55
# T 422
# ☒ 431
# ---
# Q 600+257
# T 857
# ☒ 895
# ---
# Q 761+292
# T 1053
# ☒ 1015
# ---
# Q 830+597
# T 1427
# ☒ 1493
# ---
# Q 26+838
# T 864
# ☒ 891
# ---
# Q 143+93
# T 236
# ☒ 221
# ---
# 검증 정확도 2.260%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 1.17
# | 에폭 6 |  반복 21 / 351 | 시간 1[s] | 손실 1.17
# | 에폭 6 |  반복 41 / 351 | 시간 2[s] | 손실 1.18
# | 에폭 6 |  반복 61 / 351 | 시간 3[s] | 손실 1.17
# | 에폭 6 |  반복 81 / 351 | 시간 5[s] | 손실 1.16
# | 에폭 6 |  반복 101 / 351 | 시간 6[s] | 손실 1.16
# | 에폭 6 |  반복 121 / 351 | 시간 7[s] | 손실 1.16
# | 에폭 6 |  반복 141 / 351 | 시간 9[s] | 손실 1.14
# | 에폭 6 |  반복 161 / 351 | 시간 10[s] | 손실 1.14
# | 에폭 6 |  반복 181 / 351 | 시간 11[s] | 손실 1.13
# | 에폭 6 |  반복 201 / 351 | 시간 13[s] | 손실 1.15
# | 에폭 6 |  반복 221 / 351 | 시간 14[s] | 손실 1.13
# | 에폭 6 |  반복 241 / 351 | 시간 15[s] | 손실 1.14
# | 에폭 6 |  반복 261 / 351 | 시간 17[s] | 손실 1.12
# | 에폭 6 |  반복 281 / 351 | 시간 18[s] | 손실 1.12
# | 에폭 6 |  반복 301 / 351 | 시간 19[s] | 손실 1.12
# | 에폭 6 |  반복 321 / 351 | 시간 20[s] | 손실 1.10
# | 에폭 6 |  반복 341 / 351 | 시간 22[s] | 손실 1.10
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1169
# ---
# Q 582+84
# T 666
# ☒ 660
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 412
# ---
# Q 600+257
# T 857
# ☒ 846
# ---
# Q 761+292
# T 1053
# ☒ 1011
# ---
# Q 830+597
# T 1427
# ☒ 1412
# ---
# Q 26+838
# T 864
# ☒ 846
# ---
# Q 143+93
# T 236
# ☒ 207
# ---
# 검증 정확도 2.100%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 1.11
# | 에폭 7 |  반복 21 / 351 | 시간 1[s] | 손실 1.09
# | 에폭 7 |  반복 41 / 351 | 시간 2[s] | 손실 1.09
# | 에폭 7 |  반복 61 / 351 | 시간 3[s] | 손실 1.10
# | 에폭 7 |  반복 81 / 351 | 시간 5[s] | 손실 1.09
# | 에폭 7 |  반복 101 / 351 | 시간 6[s] | 손실 1.08
# | 에폭 7 |  반복 121 / 351 | 시간 7[s] | 손실 1.08
# | 에폭 7 |  반복 141 / 351 | 시간 9[s] | 손실 1.08
# | 에폭 7 |  반복 161 / 351 | 시간 10[s] | 손실 1.09
# | 에폭 7 |  반복 181 / 351 | 시간 11[s] | 손실 1.11
# | 에폭 7 |  반복 201 / 351 | 시간 12[s] | 손실 1.07
# | 에폭 7 |  반복 221 / 351 | 시간 14[s] | 손실 1.06
# | 에폭 7 |  반복 241 / 351 | 시간 15[s] | 손실 1.06
# | 에폭 7 |  반복 261 / 351 | 시간 16[s] | 손실 1.06
# | 에폭 7 |  반복 281 / 351 | 시간 18[s] | 손실 1.05
# | 에폭 7 |  반복 301 / 351 | 시간 19[s] | 손실 1.05
# | 에폭 7 |  반복 321 / 351 | 시간 20[s] | 손실 1.05
# | 에폭 7 |  반복 341 / 351 | 시간 21[s] | 손실 1.04
# Q 77+85
# T 162
# ☒ 156
# ---
# Q 975+164
# T 1139
# ☒ 1121
# ---
# Q 582+84
# T 666
# ☒ 656
# ---
# Q 8+155
# T 163
# ☒ 146
# ---
# Q 367+55
# T 422
# ☒ 412
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1031
# ---
# Q 830+597
# T 1427
# ☒ 1374
# ---
# Q 26+838
# T 864
# ☒ 854
# ---
# Q 143+93
# T 236
# ☒ 217
# ---
# 검증 정확도 3.060%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 1.06
# | 에폭 8 |  반복 21 / 351 | 시간 1[s] | 손실 1.05
# | 에폭 8 |  반복 41 / 351 | 시간 2[s] | 손실 1.10
# | 에폭 8 |  반복 61 / 351 | 시간 3[s] | 손실 1.09
# | 에폭 8 |  반복 81 / 351 | 시간 5[s] | 손실 1.08
# | 에폭 8 |  반복 101 / 351 | 시간 6[s] | 손실 1.04
# | 에폭 8 |  반복 121 / 351 | 시간 7[s] | 손실 1.03
# | 에폭 8 |  반복 141 / 351 | 시간 9[s] | 손실 1.04
# | 에폭 8 |  반복 161 / 351 | 시간 10[s] | 손실 1.05
# | 에폭 8 |  반복 181 / 351 | 시간 11[s] | 손실 1.03
# | 에폭 8 |  반복 201 / 351 | 시간 12[s] | 손실 1.03
# | 에폭 8 |  반복 221 / 351 | 시간 14[s] | 손실 1.02
# | 에폭 8 |  반복 241 / 351 | 시간 15[s] | 손실 1.01
# | 에폭 8 |  반복 261 / 351 | 시간 16[s] | 손실 1.01
# | 에폭 8 |  반복 281 / 351 | 시간 18[s] | 손실 1.02
# | 에폭 8 |  반복 301 / 351 | 시간 19[s] | 손실 1.03
# | 에폭 8 |  반복 321 / 351 | 시간 20[s] | 손실 1.05
# | 에폭 8 |  반복 341 / 351 | 시간 21[s] | 손실 1.05
# Q 77+85
# T 162
# ☒ 156
# ---
# Q 975+164
# T 1139
# ☒ 1108
# ---
# Q 582+84
# T 666
# ☒ 651
# ---
# Q 8+155
# T 163
# ☒ 153
# ---
# Q 367+55
# T 422
# ☒ 400
# ---
# Q 600+257
# T 857
# ☒ 833
# ---
# Q 761+292
# T 1053
# ☒ 1004
# ---
# Q 830+597
# T 1427
# ☒ 1431
# ---
# Q 26+838
# T 864
# ☒ 853
# ---
# Q 143+93
# T 236
# ☒ 207
# ---
# 검증 정확도 1.400%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 1.05
# | 에폭 9 |  반복 21 / 351 | 시간 1[s] | 손실 1.05
# | 에폭 9 |  반복 41 / 351 | 시간 2[s] | 손실 1.02
# | 에폭 9 |  반복 61 / 351 | 시간 3[s] | 손실 0.99
# | 에폭 9 |  반복 81 / 351 | 시간 5[s] | 손실 0.99
# | 에폭 9 |  반복 101 / 351 | 시간 6[s] | 손실 0.99
# | 에폭 9 |  반복 121 / 351 | 시간 7[s] | 손실 1.00
# | 에폭 9 |  반복 141 / 351 | 시간 9[s] | 손실 1.00
# | 에폭 9 |  반복 161 / 351 | 시간 10[s] | 손실 0.99
# | 에폭 9 |  반복 181 / 351 | 시간 11[s] | 손실 0.98
# | 에폭 9 |  반복 201 / 351 | 시간 13[s] | 손실 0.99
# | 에폭 9 |  반복 221 / 351 | 시간 14[s] | 손실 0.99
# | 에폭 9 |  반복 241 / 351 | 시간 15[s] | 손실 1.00
# | 에폭 9 |  반복 261 / 351 | 시간 16[s] | 손실 1.01
# | 에폭 9 |  반복 281 / 351 | 시간 18[s] | 손실 0.99
# | 에폭 9 |  반복 301 / 351 | 시간 19[s] | 손실 1.02
# | 에폭 9 |  반복 321 / 351 | 시간 20[s] | 손실 1.02
# | 에폭 9 |  반복 341 / 351 | 시간 22[s] | 손실 1.01
# Q 77+85
# T 162
# ☒ 157
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 167
# ---
# Q 367+55
# T 422
# ☒ 410
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1417
# ---
# Q 26+838
# T 864
# ☒ 857
# ---
# Q 143+93
# T 236
# ☒ 218
# ---
# 검증 정확도 3.480%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.99
# | 에폭 10 |  반복 21 / 351 | 시간 1[s] | 손실 1.00
# | 에폭 10 |  반복 41 / 351 | 시간 2[s] | 손실 1.00
# | 에폭 10 |  반복 61 / 351 | 시간 3[s] | 손실 1.01
# | 에폭 10 |  반복 81 / 351 | 시간 5[s] | 손실 0.96
# | 에폭 10 |  반복 101 / 351 | 시간 6[s] | 손실 0.96
# | 에폭 10 |  반복 121 / 351 | 시간 7[s] | 손실 0.96
# | 에폭 10 |  반복 141 / 351 | 시간 9[s] | 손실 1.04
# | 에폭 10 |  반복 161 / 351 | 시간 10[s] | 손실 1.06
# | 에폭 10 |  반복 181 / 351 | 시간 11[s] | 손실 1.06
# | 에폭 10 |  반복 201 / 351 | 시간 13[s] | 손실 1.05
# | 에폭 10 |  반복 221 / 351 | 시간 14[s] | 손실 1.04
# | 에폭 10 |  반복 241 / 351 | 시간 15[s] | 손실 0.99
# | 에폭 10 |  반복 261 / 351 | 시간 16[s] | 손실 0.96
# | 에폭 10 |  반복 281 / 351 | 시간 18[s] | 손실 0.95
# | 에폭 10 |  반복 301 / 351 | 시간 19[s] | 손실 0.95
# | 에폭 10 |  반복 321 / 351 | 시간 21[s] | 손실 0.95
# | 에폭 10 |  반복 341 / 351 | 시간 22[s] | 손실 0.94
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 170
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 241
# ---
# 검증 정확도 5.400%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 11 |  반복 21 / 351 | 시간 1[s] | 손실 0.98
# | 에폭 11 |  반복 41 / 351 | 시간 2[s] | 손실 0.96
# | 에폭 11 |  반복 61 / 351 | 시간 3[s] | 손실 0.94
# | 에폭 11 |  반복 81 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 11 |  반복 101 / 351 | 시간 6[s] | 손실 0.98
# | 에폭 11 |  반복 121 / 351 | 시간 7[s] | 손실 0.96
# | 에폭 11 |  반복 141 / 351 | 시간 9[s] | 손실 0.94
# | 에폭 11 |  반복 161 / 351 | 시간 10[s] | 손실 0.94
# | 에폭 11 |  반복 181 / 351 | 시간 11[s] | 손실 0.95
# | 에폭 11 |  반복 201 / 351 | 시간 13[s] | 손실 0.93
# | 에폭 11 |  반복 221 / 351 | 시간 14[s] | 손실 0.93
# | 에폭 11 |  반복 241 / 351 | 시간 15[s] | 손실 0.92
# | 에폭 11 |  반복 261 / 351 | 시간 17[s] | 손실 0.94
# | 에폭 11 |  반복 281 / 351 | 시간 18[s] | 손실 0.93
# | 에폭 11 |  반복 301 / 351 | 시간 19[s] | 손실 0.93
# | 에폭 11 |  반복 321 / 351 | 시간 21[s] | 손실 0.94
# | 에폭 11 |  반복 341 / 351 | 시간 22[s] | 손실 0.95
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1121
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 172
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 5.900%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 12 |  반복 21 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 12 |  반복 41 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 12 |  반복 61 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 12 |  반복 81 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 12 |  반복 101 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 12 |  반복 121 / 351 | 시간 7[s] | 손실 0.92
# | 에폭 12 |  반복 141 / 351 | 시간 9[s] | 손실 0.93
# | 에폭 12 |  반복 161 / 351 | 시간 10[s] | 손실 0.97
# | 에폭 12 |  반복 181 / 351 | 시간 11[s] | 손실 0.98
# | 에폭 12 |  반복 201 / 351 | 시간 12[s] | 손실 0.92
# | 에폭 12 |  반복 221 / 351 | 시간 14[s] | 손실 0.94
# | 에폭 12 |  반복 241 / 351 | 시간 15[s] | 손실 0.91
# | 에폭 12 |  반복 261 / 351 | 시간 16[s] | 손실 0.91
# | 에폭 12 |  반복 281 / 351 | 시간 18[s] | 손실 0.91
# | 에폭 12 |  반복 301 / 351 | 시간 19[s] | 손실 0.90
# | 에폭 12 |  반복 321 / 351 | 시간 20[s] | 손실 0.91
# | 에폭 12 |  반복 341 / 351 | 시간 22[s] | 손실 0.91
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1129
# ---
# Q 582+84
# T 666
# ☒ 671
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 229
# ---
# 검증 정확도 7.340%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 13 |  반복 21 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 13 |  반복 41 / 351 | 시간 2[s] | 손실 0.90
# | 에폭 13 |  반복 61 / 351 | 시간 4[s] | 손실 0.94
# | 에폭 13 |  반복 81 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 13 |  반복 101 / 351 | 시간 6[s] | 손실 0.91
# | 에폭 13 |  반복 121 / 351 | 시간 8[s] | 손실 0.91
# | 에폭 13 |  반복 141 / 351 | 시간 9[s] | 손실 0.89
# | 에폭 13 |  반복 161 / 351 | 시간 10[s] | 손실 0.92
# | 에폭 13 |  반복 181 / 351 | 시간 12[s] | 손실 0.93
# | 에폭 13 |  반복 201 / 351 | 시간 13[s] | 손실 0.90
# | 에폭 13 |  반복 221 / 351 | 시간 14[s] | 손실 0.89
# | 에폭 13 |  반복 241 / 351 | 시간 15[s] | 손실 0.91
# | 에폭 13 |  반복 261 / 351 | 시간 17[s] | 손실 0.93
# | 에폭 13 |  반복 281 / 351 | 시간 18[s] | 손실 0.90
# | 에폭 13 |  반복 301 / 351 | 시간 19[s] | 손실 0.88
# | 에폭 13 |  반복 321 / 351 | 시간 21[s] | 손실 0.89
# | 에폭 13 |  반복 341 / 351 | 시간 22[s] | 손실 0.89
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1121
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1441
# ---
# Q 26+838
# T 864
# ☒ 869
# ---
# Q 143+93
# T 236
# ☒ 246
# ---
# 검증 정확도 7.000%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.91
# | 에폭 14 |  반복 21 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 14 |  반복 41 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 14 |  반복 61 / 351 | 시간 4[s] | 손실 0.89
# | 에폭 14 |  반복 81 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 14 |  반복 101 / 351 | 시간 6[s] | 손실 0.88
# | 에폭 14 |  반복 121 / 351 | 시간 7[s] | 손실 0.86
# | 에폭 14 |  반복 141 / 351 | 시간 9[s] | 손실 0.89
# | 에폭 14 |  반복 161 / 351 | 시간 10[s] | 손실 0.88
# | 에폭 14 |  반복 181 / 351 | 시간 11[s] | 손실 0.88
# | 에폭 14 |  반복 201 / 351 | 시간 13[s] | 손실 0.87
# | 에폭 14 |  반복 221 / 351 | 시간 14[s] | 손실 0.88
# | 에폭 14 |  반복 241 / 351 | 시간 15[s] | 손실 0.88
# | 에폭 14 |  반복 261 / 351 | 시간 17[s] | 손실 0.88
# | 에폭 14 |  반복 281 / 351 | 시간 18[s] | 손실 0.90
# | 에폭 14 |  반복 301 / 351 | 시간 19[s] | 손실 0.88
# | 에폭 14 |  반복 321 / 351 | 시간 21[s] | 손실 0.90
# | 에폭 14 |  반복 341 / 351 | 시간 22[s] | 손실 0.91
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1162
# ---
# Q 582+84
# T 666
# ☒ 681
# ---
# Q 8+155
# T 163
# ☒ 168
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1072
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 875
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 5.060%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 15 |  반복 21 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 15 |  반복 41 / 351 | 시간 2[s] | 손실 0.86
# | 에폭 15 |  반복 61 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 15 |  반복 81 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 15 |  반복 101 / 351 | 시간 6[s] | 손실 0.88
# | 에폭 15 |  반복 121 / 351 | 시간 7[s] | 손실 0.90
# | 에폭 15 |  반복 141 / 351 | 시간 9[s] | 손실 0.88
# | 에폭 15 |  반복 161 / 351 | 시간 10[s] | 손실 0.87
# | 에폭 15 |  반복 181 / 351 | 시간 11[s] | 손실 0.87
# | 에폭 15 |  반복 201 / 351 | 시간 13[s] | 손실 0.86
# | 에폭 15 |  반복 221 / 351 | 시간 14[s] | 손실 0.87
# | 에폭 15 |  반복 241 / 351 | 시간 15[s] | 손실 0.86
# | 에폭 15 |  반복 261 / 351 | 시간 17[s] | 손실 0.91
# | 에폭 15 |  반복 281 / 351 | 시간 18[s] | 손실 0.90
# | 에폭 15 |  반복 301 / 351 | 시간 19[s] | 손실 0.94
# | 에폭 15 |  반복 321 / 351 | 시간 20[s] | 손실 0.86
# | 에폭 15 |  반복 341 / 351 | 시간 22[s] | 손실 0.85
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1126
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 861
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 8.640%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 16 |  반복 21 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 16 |  반복 41 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 16 |  반복 61 / 351 | 시간 3[s] | 손실 0.89
# | 에폭 16 |  반복 81 / 351 | 시간 5[s] | 손실 0.87
# | 에폭 16 |  반복 101 / 351 | 시간 6[s] | 손실 0.89
# | 에폭 16 |  반복 121 / 351 | 시간 7[s] | 손실 0.87
# | 에폭 16 |  반복 141 / 351 | 시간 9[s] | 손실 0.87
# | 에폭 16 |  반복 161 / 351 | 시간 10[s] | 손실 0.85
# | 에폭 16 |  반복 181 / 351 | 시간 11[s] | 손실 0.86
# | 에폭 16 |  반복 201 / 351 | 시간 13[s] | 손실 0.85
# | 에폭 16 |  반복 221 / 351 | 시간 14[s] | 손실 0.89
# | 에폭 16 |  반복 241 / 351 | 시간 15[s] | 손실 0.88
# | 에폭 16 |  반복 261 / 351 | 시간 16[s] | 손실 0.87
# | 에폭 16 |  반복 281 / 351 | 시간 18[s] | 손실 0.87
# | 에폭 16 |  반복 301 / 351 | 시간 19[s] | 손실 0.84
# | 에폭 16 |  반복 321 / 351 | 시간 20[s] | 손실 0.86
# | 에폭 16 |  반복 341 / 351 | 시간 22[s] | 손실 0.86
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1107
# ---
# Q 582+84
# T 666
# ☒ 659
# ---
# Q 8+155
# T 163
# ☒ 159
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 859
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 5.980%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 17 |  반복 21 / 351 | 시간 1[s] | 손실 0.86
# | 에폭 17 |  반복 41 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 17 |  반복 61 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 17 |  반복 81 / 351 | 시간 5[s] | 손실 0.87
# | 에폭 17 |  반복 101 / 351 | 시간 6[s] | 손실 0.90
# | 에폭 17 |  반복 121 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 17 |  반복 141 / 351 | 시간 9[s] | 손실 0.85
# | 에폭 17 |  반복 161 / 351 | 시간 10[s] | 손실 0.84
# | 에폭 17 |  반복 181 / 351 | 시간 11[s] | 손실 0.85
# | 에폭 17 |  반복 201 / 351 | 시간 12[s] | 손실 0.84
# | 에폭 17 |  반복 221 / 351 | 시간 14[s] | 손실 0.83
# | 에폭 17 |  반복 241 / 351 | 시간 15[s] | 손실 0.86
# | 에폭 17 |  반복 261 / 351 | 시간 16[s] | 손실 0.85
# | 에폭 17 |  반복 281 / 351 | 시간 18[s] | 손실 0.85
# | 에폭 17 |  반복 301 / 351 | 시간 19[s] | 손실 0.86
# | 에폭 17 |  반복 321 / 351 | 시간 20[s] | 손실 0.86
# | 에폭 17 |  반복 341 / 351 | 시간 21[s] | 손실 0.87
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1161
# ---
# Q 582+84
# T 666
# ☒ 671
# ---
# Q 8+155
# T 163
# ☒ 171
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1071
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 6.340%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.85
# | 에폭 18 |  반복 21 / 351 | 시간 1[s] | 손실 0.85
# | 에폭 18 |  반복 41 / 351 | 시간 2[s] | 손실 0.85
# | 에폭 18 |  반복 61 / 351 | 시간 4[s] | 손실 0.85
# | 에폭 18 |  반복 81 / 351 | 시간 5[s] | 손실 0.85
# | 에폭 18 |  반복 101 / 351 | 시간 6[s] | 손실 0.85
# | 에폭 18 |  반복 121 / 351 | 시간 7[s] | 손실 0.87
# | 에폭 18 |  반복 141 / 351 | 시간 9[s] | 손실 0.87
# | 에폭 18 |  반복 161 / 351 | 시간 10[s] | 손실 0.84
# | 에폭 18 |  반복 181 / 351 | 시간 11[s] | 손실 0.84
# | 에폭 18 |  반복 201 / 351 | 시간 13[s] | 손실 0.83
# | 에폭 18 |  반복 221 / 351 | 시간 14[s] | 손실 0.82
# | 에폭 18 |  반복 241 / 351 | 시간 15[s] | 손실 0.85
# | 에폭 18 |  반복 261 / 351 | 시간 17[s] | 손실 0.86
# | 에폭 18 |  반복 281 / 351 | 시간 18[s] | 손실 0.86
# | 에폭 18 |  반복 301 / 351 | 시간 19[s] | 손실 0.82
# | 에폭 18 |  반복 321 / 351 | 시간 20[s] | 손실 0.83
# | 에폭 18 |  반복 341 / 351 | 시간 22[s] | 손실 0.84
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1128
# ---
# Q 582+84
# T 666
# ☒ 659
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☒ 841
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 851
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 5.560%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 19 |  반복 21 / 351 | 시간 1[s] | 손실 0.85
# | 에폭 19 |  반복 41 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 19 |  반복 61 / 351 | 시간 3[s] | 손실 0.83
# | 에폭 19 |  반복 81 / 351 | 시간 5[s] | 손실 0.84
# | 에폭 19 |  반복 101 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 19 |  반복 121 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 19 |  반복 141 / 351 | 시간 9[s] | 손실 0.84
# | 에폭 19 |  반복 161 / 351 | 시간 10[s] | 손실 0.83
# | 에폭 19 |  반복 181 / 351 | 시간 11[s] | 손실 0.83
# | 에폭 19 |  반복 201 / 351 | 시간 13[s] | 손실 0.83
# | 에폭 19 |  반복 221 / 351 | 시간 14[s] | 손실 0.85
# | 에폭 19 |  반복 241 / 351 | 시간 15[s] | 손실 0.83
# | 에폭 19 |  반복 261 / 351 | 시간 16[s] | 손실 0.83
# | 에폭 19 |  반복 281 / 351 | 시간 18[s] | 손실 0.82
# | 에폭 19 |  반복 301 / 351 | 시간 19[s] | 손실 0.82
# | 에폭 19 |  반복 321 / 351 | 시간 20[s] | 손실 0.81
# | 에폭 19 |  반복 341 / 351 | 시간 22[s] | 손실 0.85
# Q 77+85
# T 162
# ☒ 157
# ---
# Q 975+164
# T 1139
# ☒ 1126
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 157
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 841
# ---
# Q 761+292
# T 1053
# ☒ 1036
# ---
# Q 830+597
# T 1427
# ☒ 1414
# ---
# Q 26+838
# T 864
# ☒ 851
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 4.520%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 20 |  반복 21 / 351 | 시간 1[s] | 손실 0.83
# | 에폭 20 |  반복 41 / 351 | 시간 2[s] | 손실 0.85
# | 에폭 20 |  반복 61 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 20 |  반복 81 / 351 | 시간 5[s] | 손실 0.84
# | 에폭 20 |  반복 101 / 351 | 시간 6[s] | 손실 0.83
# | 에폭 20 |  반복 121 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 20 |  반복 141 / 351 | 시간 8[s] | 손실 0.83
# | 에폭 20 |  반복 161 / 351 | 시간 10[s] | 손실 0.84
# | 에폭 20 |  반복 181 / 351 | 시간 11[s] | 손실 0.81
# | 에폭 20 |  반복 201 / 351 | 시간 12[s] | 손실 0.81
# | 에폭 20 |  반복 221 / 351 | 시간 14[s] | 손실 0.80
# | 에폭 20 |  반복 241 / 351 | 시간 15[s] | 손실 0.80
# | 에폭 20 |  반복 261 / 351 | 시간 16[s] | 손실 0.81
# | 에폭 20 |  반복 281 / 351 | 시간 17[s] | 손실 0.81
# | 에폭 20 |  반복 301 / 351 | 시간 19[s] | 손실 0.84
# | 에폭 20 |  반복 321 / 351 | 시간 20[s] | 손실 0.84
# | 에폭 20 |  반복 341 / 351 | 시간 21[s] | 손실 0.87
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1126
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 157
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 846
# ---
# Q 761+292
# T 1053
# ☒ 1036
# ---
# Q 830+597
# T 1427
# ☒ 1414
# ---
# Q 26+838
# T 864
# ☒ 858
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 6.920%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 21 |  반복 21 / 351 | 시간 1[s] | 손실 0.80
# | 에폭 21 |  반복 41 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 21 |  반복 61 / 351 | 시간 3[s] | 손실 0.81
# | 에폭 21 |  반복 81 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 21 |  반복 101 / 351 | 시간 6[s] | 손실 0.83
# | 에폭 21 |  반복 121 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 21 |  반복 141 / 351 | 시간 9[s] | 손실 0.81
# | 에폭 21 |  반복 161 / 351 | 시간 10[s] | 손실 0.80
# | 에폭 21 |  반복 181 / 351 | 시간 11[s] | 손실 0.79
# | 에폭 21 |  반복 201 / 351 | 시간 12[s] | 손실 0.82
# | 에폭 21 |  반복 221 / 351 | 시간 14[s] | 손실 0.82
# | 에폭 21 |  반복 241 / 351 | 시간 15[s] | 손실 0.79
# | 에폭 21 |  반복 261 / 351 | 시간 16[s] | 손실 0.80
# | 에폭 21 |  반복 281 / 351 | 시간 18[s] | 손실 0.83
# | 에폭 21 |  반복 301 / 351 | 시간 19[s] | 손실 0.84
# | 에폭 21 |  반복 321 / 351 | 시간 20[s] | 손실 0.82
# | 에폭 21 |  반복 341 / 351 | 시간 21[s] | 손실 0.82
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1126
# ---
# Q 582+84
# T 666
# ☒ 655
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 417
# ---
# Q 600+257
# T 857
# ☒ 846
# ---
# Q 761+292
# T 1053
# ☒ 1046
# ---
# Q 830+597
# T 1427
# ☒ 1414
# ---
# Q 26+838
# T 864
# ☒ 858
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 5.500%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 22 |  반복 21 / 351 | 시간 1[s] | 손실 0.81
# | 에폭 22 |  반복 41 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 22 |  반복 61 / 351 | 시간 3[s] | 손실 0.81
# | 에폭 22 |  반복 81 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 22 |  반복 101 / 351 | 시간 6[s] | 손실 0.80
# | 에폭 22 |  반복 121 / 351 | 시간 7[s] | 손실 0.79
# | 에폭 22 |  반복 141 / 351 | 시간 9[s] | 손실 0.79
# | 에폭 22 |  반복 161 / 351 | 시간 10[s] | 손실 0.84
# | 에폭 22 |  반복 181 / 351 | 시간 11[s] | 손실 0.82
# | 에폭 22 |  반복 201 / 351 | 시간 12[s] | 손실 0.81
# | 에폭 22 |  반복 221 / 351 | 시간 14[s] | 손실 0.80
# | 에폭 22 |  반복 241 / 351 | 시간 15[s] | 손실 0.80
# | 에폭 22 |  반복 261 / 351 | 시간 16[s] | 손실 0.81
# | 에폭 22 |  반복 281 / 351 | 시간 18[s] | 손실 0.80
# | 에폭 22 |  반복 301 / 351 | 시간 19[s] | 손실 0.80
# | 에폭 22 |  반복 321 / 351 | 시간 20[s] | 손실 0.78
# | 에폭 22 |  반복 341 / 351 | 시간 21[s] | 손실 0.79
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1127
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 167
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 855
# ---
# Q 761+292
# T 1053
# ☒ 1055
# ---
# Q 830+597
# T 1427
# ☒ 1417
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# 검증 정확도 9.240%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.76
# | 에폭 23 |  반복 21 / 351 | 시간 1[s] | 손실 0.77
# | 에폭 23 |  반복 41 / 351 | 시간 2[s] | 손실 0.79
# | 에폭 23 |  반복 61 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 23 |  반복 81 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 23 |  반복 101 / 351 | 시간 6[s] | 손실 0.80
# | 에폭 23 |  반복 121 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 23 |  반복 141 / 351 | 시간 8[s] | 손실 0.81
# | 에폭 23 |  반복 161 / 351 | 시간 10[s] | 손실 0.81
# | 에폭 23 |  반복 181 / 351 | 시간 11[s] | 손실 0.79
# | 에폭 23 |  반복 201 / 351 | 시간 12[s] | 손실 0.82
# | 에폭 23 |  반복 221 / 351 | 시간 14[s] | 손실 0.79
# | 에폭 23 |  반복 241 / 351 | 시간 15[s] | 손실 0.79
# | 에폭 23 |  반복 261 / 351 | 시간 16[s] | 손실 0.82
# | 에폭 23 |  반복 281 / 351 | 시간 17[s] | 손실 0.80
# | 에폭 23 |  반복 301 / 351 | 시간 19[s] | 손실 0.77
# | 에폭 23 |  반복 321 / 351 | 시간 20[s] | 손실 0.76
# | 에폭 23 |  반복 341 / 351 | 시간 21[s] | 손실 0.80
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 167
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1415
# ---
# Q 26+838
# T 864
# ☒ 858
# ---
# Q 143+93
# T 236
# ☒ 232
# ---
# 검증 정확도 6.880%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.77
# | 에폭 24 |  반복 21 / 351 | 시간 1[s] | 손실 0.78
# | 에폭 24 |  반복 41 / 351 | 시간 2[s] | 손실 0.78
# | 에폭 24 |  반복 61 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 24 |  반복 81 / 351 | 시간 5[s] | 손실 0.79
# | 에폭 24 |  반복 101 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 24 |  반복 121 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 24 |  반복 141 / 351 | 시간 9[s] | 손실 0.79
# | 에폭 24 |  반복 161 / 351 | 시간 10[s] | 손실 0.79
# | 에폭 24 |  반복 181 / 351 | 시간 11[s] | 손실 0.79
# | 에폭 24 |  반복 201 / 351 | 시간 12[s] | 손실 0.80
# | 에폭 24 |  반복 221 / 351 | 시간 14[s] | 손실 0.80
# | 에폭 24 |  반복 241 / 351 | 시간 15[s] | 손실 0.81
# | 에폭 24 |  반복 261 / 351 | 시간 16[s] | 손실 0.80
# | 에폭 24 |  반복 281 / 351 | 시간 18[s] | 손실 0.76
# | 에폭 24 |  반복 301 / 351 | 시간 19[s] | 손실 0.75
# | 에폭 24 |  반복 321 / 351 | 시간 20[s] | 손실 0.76
# | 에폭 24 |  반복 341 / 351 | 시간 21[s] | 손실 0.77
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1129
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 157
# ---
# Q 367+55
# T 422
# ☒ 417
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 229
# ---
# 검증 정확도 10.960%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.75
# | 에폭 25 |  반복 21 / 351 | 시간 1[s] | 손실 0.76
# | 에폭 25 |  반복 41 / 351 | 시간 2[s] | 손실 0.77
# | 에폭 25 |  반복 61 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 25 |  반복 81 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 25 |  반복 101 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 25 |  반복 121 / 351 | 시간 7[s] | 손실 0.78
# | 에폭 25 |  반복 141 / 351 | 시간 9[s] | 손실 0.76
# | 에폭 25 |  반복 161 / 351 | 시간 10[s] | 손실 0.75
# | 에폭 25 |  반복 181 / 351 | 시간 11[s] | 손실 0.77
# | 에폭 25 |  반복 201 / 351 | 시간 12[s] | 손실 0.77
# | 에폭 25 |  반복 221 / 351 | 시간 14[s] | 손실 0.78
# | 에폭 25 |  반복 241 / 351 | 시간 15[s] | 손실 0.76
# | 에폭 25 |  반복 261 / 351 | 시간 16[s] | 손실 0.77
# | 에폭 25 |  반복 281 / 351 | 시간 18[s] | 손실 0.79
# | 에폭 25 |  반복 301 / 351 | 시간 19[s] | 손실 0.78
# | 에폭 25 |  반복 321 / 351 | 시간 20[s] | 손실 0.76
# | 에폭 25 |  반복 341 / 351 | 시간 21[s] | 손실 0.76
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☒ 658
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 9.600%
# | 에폭 26 |  반복 1 / 351 | 시간 0[s] | 손실 0.76
# | 에폭 26 |  반복 21 / 351 | 시간 1[s] | 손실 0.76
# | 에폭 26 |  반복 41 / 351 | 시간 2[s] | 손실 0.76
# | 에폭 26 |  반복 61 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 26 |  반복 81 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 26 |  반복 101 / 351 | 시간 6[s] | 손실 0.78
# | 에폭 26 |  반복 121 / 351 | 시간 7[s] | 손실 0.75
# | 에폭 26 |  반복 141 / 351 | 시간 9[s] | 손실 0.75
# | 에폭 26 |  반복 161 / 351 | 시간 10[s] | 손실 0.76
# | 에폭 26 |  반복 181 / 351 | 시간 11[s] | 손실 0.81
# | 에폭 26 |  반복 201 / 351 | 시간 12[s] | 손실 0.76
# | 에폭 26 |  반복 221 / 351 | 시간 14[s] | 손실 0.78
# | 에폭 26 |  반복 241 / 351 | 시간 15[s] | 손실 0.76
# | 에폭 26 |  반복 261 / 351 | 시간 16[s] | 손실 0.76
# | 에폭 26 |  반복 281 / 351 | 시간 18[s] | 손실 0.74
# | 에폭 26 |  반복 301 / 351 | 시간 19[s] | 손실 0.75
# | 에폭 26 |  반복 321 / 351 | 시간 20[s] | 손실 0.79
# | 에폭 26 |  반복 341 / 351 | 시간 21[s] | 손실 0.77
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1128
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1036
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 858
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 10.600%
# | 에폭 27 |  반복 1 / 351 | 시간 0[s] | 손실 0.71
# | 에폭 27 |  반복 21 / 351 | 시간 1[s] | 손실 0.73
# | 에폭 27 |  반복 41 / 351 | 시간 2[s] | 손실 0.76
# | 에폭 27 |  반복 61 / 351 | 시간 3[s] | 손실 0.74
# | 에폭 27 |  반복 81 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 27 |  반복 101 / 351 | 시간 6[s] | 손실 0.77
# | 에폭 27 |  반복 121 / 351 | 시간 7[s] | 손실 0.77
# | 에폭 27 |  반복 141 / 351 | 시간 9[s] | 손실 0.73
# | 에폭 27 |  반복 161 / 351 | 시간 10[s] | 손실 0.78
# | 에폭 27 |  반복 181 / 351 | 시간 11[s] | 손실 0.77
# | 에폭 27 |  반복 201 / 351 | 시간 12[s] | 손실 0.75
# | 에폭 27 |  반복 221 / 351 | 시간 14[s] | 손실 0.76
# | 에폭 27 |  반복 241 / 351 | 시간 15[s] | 손실 0.76
# | 에폭 27 |  반복 261 / 351 | 시간 16[s] | 손실 0.76
# | 에폭 27 |  반복 281 / 351 | 시간 18[s] | 손실 0.77
# | 에폭 27 |  반복 301 / 351 | 시간 19[s] | 손실 0.77
# | 에폭 27 |  반복 321 / 351 | 시간 20[s] | 손실 0.76
# | 에폭 27 |  반복 341 / 351 | 시간 21[s] | 손실 0.78
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1163
# ---
# Q 582+84
# T 666
# ☒ 672
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1073
# ---
# Q 830+597
# T 1427
# ☒ 1444
# ---
# Q 26+838
# T 864
# ☒ 871
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 7.500%
# | 에폭 28 |  반복 1 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 28 |  반복 21 / 351 | 시간 1[s] | 손실 0.75
# | 에폭 28 |  반복 41 / 351 | 시간 2[s] | 손실 0.74
# | 에폭 28 |  반복 61 / 351 | 시간 3[s] | 손실 0.75
# | 에폭 28 |  반복 81 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 28 |  반복 101 / 351 | 시간 6[s] | 손실 0.78
# | 에폭 28 |  반복 121 / 351 | 시간 7[s] | 손실 0.77
# | 에폭 28 |  반복 141 / 351 | 시간 9[s] | 손실 0.76
# | 에폭 28 |  반복 161 / 351 | 시간 10[s] | 손실 0.76
# | 에폭 28 |  반복 181 / 351 | 시간 11[s] | 손실 0.76
# | 에폭 28 |  반복 201 / 351 | 시간 12[s] | 손실 0.77
# | 에폭 28 |  반복 221 / 351 | 시간 14[s] | 손실 0.76
# | 에폭 28 |  반복 241 / 351 | 시간 15[s] | 손실 0.75
# | 에폭 28 |  반복 261 / 351 | 시간 16[s] | 손실 0.78
# | 에폭 28 |  반복 281 / 351 | 시간 18[s] | 손실 0.73
# | 에폭 28 |  반복 301 / 351 | 시간 19[s] | 손실 0.75
# | 에폭 28 |  반복 321 / 351 | 시간 20[s] | 손실 0.74
# | 에폭 28 |  반복 341 / 351 | 시간 21[s] | 손실 0.73
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 676
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 431
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1065
# ---
# Q 830+597
# T 1427
# ☒ 1445
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 6.760%
# | 에폭 29 |  반복 1 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 29 |  반복 21 / 351 | 시간 1[s] | 손실 0.85
# | 에폭 29 |  반복 41 / 351 | 시간 2[s] | 손실 0.76
# | 에폭 29 |  반복 61 / 351 | 시간 3[s] | 손실 0.75
# | 에폭 29 |  반복 81 / 351 | 시간 5[s] | 손실 0.75
# | 에폭 29 |  반복 101 / 351 | 시간 6[s] | 손실 0.75
# | 에폭 29 |  반복 121 / 351 | 시간 7[s] | 손실 0.73
# | 에폭 29 |  반복 141 / 351 | 시간 9[s] | 손실 0.77
# | 에폭 29 |  반복 161 / 351 | 시간 10[s] | 손실 0.85
# | 에폭 29 |  반복 181 / 351 | 시간 11[s] | 손실 0.75
# | 에폭 29 |  반복 201 / 351 | 시간 12[s] | 손실 0.74
# | 에폭 29 |  반복 221 / 351 | 시간 14[s] | 손실 0.73
# | 에폭 29 |  반복 241 / 351 | 시간 15[s] | 손실 0.74
# | 에폭 29 |  반복 261 / 351 | 시간 16[s] | 손실 0.73
# | 에폭 29 |  반복 281 / 351 | 시간 18[s] | 손실 0.74
# | 에폭 29 |  반복 301 / 351 | 시간 19[s] | 손실 0.74
# | 에폭 29 |  반복 321 / 351 | 시간 20[s] | 손실 0.74
# | 에폭 29 |  반복 341 / 351 | 시간 21[s] | 손실 0.74
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1062
# ---
# Q 830+597
# T 1427
# ☒ 1415
# ---
# Q 26+838
# T 864
# ☒ 858
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# 검증 정확도 11.320%
# | 에폭 30 |  반복 1 / 351 | 시간 0[s] | 손실 0.70
# | 에폭 30 |  반복 21 / 351 | 시간 1[s] | 손실 0.73
# | 에폭 30 |  반복 41 / 351 | 시간 2[s] | 손실 0.74
# | 에폭 30 |  반복 61 / 351 | 시간 3[s] | 손실 0.73
# | 에폭 30 |  반복 81 / 351 | 시간 5[s] | 손실 0.76
# | 에폭 30 |  반복 101 / 351 | 시간 6[s] | 손실 0.76
# | 에폭 30 |  반복 121 / 351 | 시간 7[s] | 손실 0.73
# | 에폭 30 |  반복 141 / 351 | 시간 9[s] | 손실 0.75
# | 에폭 30 |  반복 161 / 351 | 시간 10[s] | 손실 0.76
# | 에폭 30 |  반복 181 / 351 | 시간 11[s] | 손실 0.75
# | 에폭 30 |  반복 201 / 351 | 시간 12[s] | 손실 0.75
# | 에폭 30 |  반복 221 / 351 | 시간 14[s] | 손실 0.72
# | 에폭 30 |  반복 241 / 351 | 시간 15[s] | 손실 0.71
# | 에폭 30 |  반복 261 / 351 | 시간 16[s] | 손실 0.72
# | 에폭 30 |  반복 281 / 351 | 시간 18[s] | 손실 0.72
# | 에폭 30 |  반복 301 / 351 | 시간 19[s] | 손실 0.84
# | 에폭 30 |  반복 321 / 351 | 시간 20[s] | 손실 0.76
# | 에폭 30 |  반복 341 / 351 | 시간 21[s] | 손실 0.71
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1129
# ---
# Q 582+84
# T 666
# ☒ 670
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1055
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 12.340%
# | 에폭 31 |  반복 1 / 351 | 시간 0[s] | 손실 0.69
# | 에폭 31 |  반복 21 / 351 | 시간 1[s] | 손실 0.74
# | 에폭 31 |  반복 41 / 351 | 시간 2[s] | 손실 0.73
# | 에폭 31 |  반복 61 / 351 | 시간 3[s] | 손실 0.70
# | 에폭 31 |  반복 81 / 351 | 시간 5[s] | 손실 0.73
# | 에폭 31 |  반복 101 / 351 | 시간 6[s] | 손실 0.74
# | 에폭 31 |  반복 121 / 351 | 시간 7[s] | 손실 0.78
# | 에폭 31 |  반복 141 / 351 | 시간 9[s] | 손실 0.71
# | 에폭 31 |  반복 161 / 351 | 시간 10[s] | 손실 0.76
# | 에폭 31 |  반복 181 / 351 | 시간 11[s] | 손실 0.76
# | 에폭 31 |  반복 201 / 351 | 시간 12[s] | 손실 0.74
# | 에폭 31 |  반복 221 / 351 | 시간 14[s] | 손실 0.71
# | 에폭 31 |  반복 241 / 351 | 시간 15[s] | 손실 0.74
# | 에폭 31 |  반복 261 / 351 | 시간 16[s] | 손실 0.72
# | 에폭 31 |  반복 281 / 351 | 시간 17[s] | 손실 0.74
# | 에폭 31 |  반복 301 / 351 | 시간 19[s] | 손실 0.75
# | 에폭 31 |  반복 321 / 351 | 시간 20[s] | 손실 0.74
# | 에폭 31 |  반복 341 / 351 | 시간 21[s] | 손실 0.71
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1107
# ---
# Q 582+84
# T 666
# ☒ 670
# ---
# Q 8+155
# T 163
# ☒ 165
# ---
# Q 367+55
# T 422
# ☒ 425
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1415
# ---
# Q 26+838
# T 864
# ☒ 863
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 12.800%
# | 에폭 32 |  반복 1 / 351 | 시간 0[s] | 손실 0.70
# | 에폭 32 |  반복 21 / 351 | 시간 1[s] | 손실 0.72
# | 에폭 32 |  반복 41 / 351 | 시간 2[s] | 손실 0.71
# | 에폭 32 |  반복 61 / 351 | 시간 3[s] | 손실 0.71
# | 에폭 32 |  반복 81 / 351 | 시간 5[s] | 손실 0.70
# | 에폭 32 |  반복 101 / 351 | 시간 6[s] | 손실 0.76
# | 에폭 32 |  반복 121 / 351 | 시간 7[s] | 손실 0.74
# | 에폭 32 |  반복 141 / 351 | 시간 9[s] | 손실 0.71
# | 에폭 32 |  반복 161 / 351 | 시간 10[s] | 손실 0.70
# | 에폭 32 |  반복 181 / 351 | 시간 11[s] | 손실 0.70
# | 에폭 32 |  반복 201 / 351 | 시간 12[s] | 손실 0.70
# | 에폭 32 |  반복 221 / 351 | 시간 14[s] | 손실 0.73
# | 에폭 32 |  반복 241 / 351 | 시간 15[s] | 손실 0.75
# | 에폭 32 |  반복 261 / 351 | 시간 16[s] | 손실 0.73
# | 에폭 32 |  반복 281 / 351 | 시간 18[s] | 손실 0.77
# | 에폭 32 |  반복 301 / 351 | 시간 19[s] | 손실 0.74
# | 에폭 32 |  반복 321 / 351 | 시간 20[s] | 손실 0.72
# | 에폭 32 |  반복 341 / 351 | 시간 21[s] | 손실 0.73
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 9.560%
# | 에폭 33 |  반복 1 / 351 | 시간 0[s] | 손실 0.72
# | 에폭 33 |  반복 21 / 351 | 시간 1[s] | 손실 0.69
# | 에폭 33 |  반복 41 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 33 |  반복 61 / 351 | 시간 3[s] | 손실 0.70
# | 에폭 33 |  반복 81 / 351 | 시간 5[s] | 손실 0.73
# | 에폭 33 |  반복 101 / 351 | 시간 6[s] | 손실 0.73
# | 에폭 33 |  반복 121 / 351 | 시간 7[s] | 손실 0.74
# | 에폭 33 |  반복 141 / 351 | 시간 9[s] | 손실 0.72
# | 에폭 33 |  반복 161 / 351 | 시간 10[s] | 손실 0.73
# | 에폭 33 |  반복 181 / 351 | 시간 11[s] | 손실 0.72
# | 에폭 33 |  반복 201 / 351 | 시간 12[s] | 손실 0.71
# | 에폭 33 |  반복 221 / 351 | 시간 14[s] | 손실 0.69
# | 에폭 33 |  반복 241 / 351 | 시간 15[s] | 손실 0.73
# | 에폭 33 |  반복 261 / 351 | 시간 16[s] | 손실 0.72
# | 에폭 33 |  반복 281 / 351 | 시간 17[s] | 손실 0.70
# | 에폭 33 |  반복 301 / 351 | 시간 19[s] | 손실 0.71
# | 에폭 33 |  반복 321 / 351 | 시간 20[s] | 손실 0.71
# | 에폭 33 |  반복 341 / 351 | 시간 21[s] | 손실 0.71
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 12.740%
# | 에폭 34 |  반복 1 / 351 | 시간 0[s] | 손실 0.68
# | 에폭 34 |  반복 21 / 351 | 시간 1[s] | 손실 0.69
# | 에폭 34 |  반복 41 / 351 | 시간 2[s] | 손실 0.69
# | 에폭 34 |  반복 61 / 351 | 시간 3[s] | 손실 0.73
# | 에폭 34 |  반복 81 / 351 | 시간 5[s] | 손실 0.71
# | 에폭 34 |  반복 101 / 351 | 시간 6[s] | 손실 0.68
# | 에폭 34 |  반복 121 / 351 | 시간 7[s] | 손실 0.69
# | 에폭 34 |  반복 141 / 351 | 시간 9[s] | 손실 0.68
# | 에폭 34 |  반복 161 / 351 | 시간 10[s] | 손실 0.67
# | 에폭 34 |  반복 181 / 351 | 시간 11[s] | 손실 0.70
# | 에폭 34 |  반복 201 / 351 | 시간 12[s] | 손실 0.74
# | 에폭 34 |  반복 221 / 351 | 시간 14[s] | 손실 0.72
# | 에폭 34 |  반복 241 / 351 | 시간 15[s] | 손실 0.71
# | 에폭 34 |  반복 261 / 351 | 시간 16[s] | 손실 0.70
# | 에폭 34 |  반복 281 / 351 | 시간 18[s] | 손실 0.70
# | 에폭 34 |  반복 301 / 351 | 시간 19[s] | 손실 0.71
# | 에폭 34 |  반복 321 / 351 | 시간 20[s] | 손실 0.71
# | 에폭 34 |  반복 341 / 351 | 시간 21[s] | 손실 0.70
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1131
# ---
# Q 582+84
# T 666
# ☒ 670
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1440
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 12.820%
# | 에폭 35 |  반복 1 / 351 | 시간 0[s] | 손실 0.67
# | 에폭 35 |  반복 21 / 351 | 시간 1[s] | 손실 0.67
# | 에폭 35 |  반복 41 / 351 | 시간 2[s] | 손실 0.72
# | 에폭 35 |  반복 61 / 351 | 시간 3[s] | 손실 0.70
# | 에폭 35 |  반복 81 / 351 | 시간 5[s] | 손실 0.73
# | 에폭 35 |  반복 101 / 351 | 시간 6[s] | 손실 0.71
# | 에폭 35 |  반복 121 / 351 | 시간 7[s] | 손실 0.73
# | 에폭 35 |  반복 141 / 351 | 시간 9[s] | 손실 0.73
# | 에폭 35 |  반복 161 / 351 | 시간 10[s] | 손실 0.71
# | 에폭 35 |  반복 181 / 351 | 시간 11[s] | 손실 0.71
# | 에폭 35 |  반복 201 / 351 | 시간 12[s] | 손실 0.71
# | 에폭 35 |  반복 221 / 351 | 시간 14[s] | 손실 0.69
# | 에폭 35 |  반복 241 / 351 | 시간 15[s] | 손실 0.68
# | 에폭 35 |  반복 261 / 351 | 시간 16[s] | 손실 0.74
# | 에폭 35 |  반복 281 / 351 | 시간 18[s] | 손실 0.72
# | 에폭 35 |  반복 301 / 351 | 시간 19[s] | 손실 0.71
# | 에폭 35 |  반복 321 / 351 | 시간 20[s] | 손실 0.71
# | 에폭 35 |  반복 341 / 351 | 시간 21[s] | 손실 0.72
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1419
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 12.180%
# | 에폭 36 |  반복 1 / 351 | 시간 0[s] | 손실 0.71
# | 에폭 36 |  반복 21 / 351 | 시간 1[s] | 손실 0.68
# | 에폭 36 |  반복 41 / 351 | 시간 2[s] | 손실 0.71
# | 에폭 36 |  반복 61 / 351 | 시간 3[s] | 손실 0.70
# | 에폭 36 |  반복 81 / 351 | 시간 5[s] | 손실 0.67
# | 에폭 36 |  반복 101 / 351 | 시간 6[s] | 손실 0.68
# | 에폭 36 |  반복 121 / 351 | 시간 7[s] | 손실 0.68
# | 에폭 36 |  반복 141 / 351 | 시간 9[s] | 손실 0.71
# | 에폭 36 |  반복 161 / 351 | 시간 10[s] | 손실 0.69
# | 에폭 36 |  반복 181 / 351 | 시간 11[s] | 손실 0.67
# | 에폭 36 |  반복 201 / 351 | 시간 12[s] | 손실 0.66
# | 에폭 36 |  반복 221 / 351 | 시간 14[s] | 손실 0.68
# | 에폭 36 |  반복 241 / 351 | 시간 15[s] | 손실 0.71
# | 에폭 36 |  반복 261 / 351 | 시간 16[s] | 손실 0.68
# | 에폭 36 |  반복 281 / 351 | 시간 18[s] | 손실 0.73
# | 에폭 36 |  반복 301 / 351 | 시간 19[s] | 손실 0.71
# | 에폭 36 |  반복 321 / 351 | 시간 20[s] | 손실 0.68
# | 에폭 36 |  반복 341 / 351 | 시간 21[s] | 손실 0.72
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1107
# ---
# Q 582+84
# T 666
# ☒ 659
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 425
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1045
# ---
# Q 830+597
# T 1427
# ☒ 1415
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 11.240%
# | 에폭 37 |  반복 1 / 351 | 시간 0[s] | 손실 0.75
# | 에폭 37 |  반복 21 / 351 | 시간 1[s] | 손실 0.66
# | 에폭 37 |  반복 41 / 351 | 시간 2[s] | 손실 0.67
# | 에폭 37 |  반복 61 / 351 | 시간 3[s] | 손실 0.68
# | 에폭 37 |  반복 81 / 351 | 시간 5[s] | 손실 0.70
# | 에폭 37 |  반복 101 / 351 | 시간 6[s] | 손실 0.66
# | 에폭 37 |  반복 121 / 351 | 시간 7[s] | 손실 0.70
# | 에폭 37 |  반복 141 / 351 | 시간 9[s] | 손실 0.67
# | 에폭 37 |  반복 161 / 351 | 시간 10[s] | 손실 0.71
# | 에폭 37 |  반복 181 / 351 | 시간 11[s] | 손실 0.69
# | 에폭 37 |  반복 201 / 351 | 시간 12[s] | 손실 0.69
# | 에폭 37 |  반복 221 / 351 | 시간 14[s] | 손실 0.69
# | 에폭 37 |  반복 241 / 351 | 시간 15[s] | 손실 0.68
# | 에폭 37 |  반복 261 / 351 | 시간 16[s] | 손실 0.69
# | 에폭 37 |  반복 281 / 351 | 시간 17[s] | 손실 0.69
# | 에폭 37 |  반복 301 / 351 | 시간 19[s] | 손실 0.67
# | 에폭 37 |  반복 321 / 351 | 시간 20[s] | 손실 0.68
# | 에폭 37 |  반복 341 / 351 | 시간 21[s] | 손실 0.67
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 12.620%
# | 에폭 38 |  반복 1 / 351 | 시간 0[s] | 손실 0.66
# | 에폭 38 |  반복 21 / 351 | 시간 1[s] | 손실 0.67
# | 에폭 38 |  반복 41 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 38 |  반복 61 / 351 | 시간 3[s] | 손실 0.71
# | 에폭 38 |  반복 81 / 351 | 시간 5[s] | 손실 0.69
# | 에폭 38 |  반복 101 / 351 | 시간 6[s] | 손실 0.69
# | 에폭 38 |  반복 121 / 351 | 시간 7[s] | 손실 0.68
# | 에폭 38 |  반복 141 / 351 | 시간 9[s] | 손실 0.67
# | 에폭 38 |  반복 161 / 351 | 시간 10[s] | 손실 0.65
# | 에폭 38 |  반복 181 / 351 | 시간 11[s] | 손실 0.67
# | 에폭 38 |  반복 201 / 351 | 시간 13[s] | 손실 0.67
# | 에폭 38 |  반복 221 / 351 | 시간 14[s] | 손실 0.67
# | 에폭 38 |  반복 241 / 351 | 시간 15[s] | 손실 0.66
# | 에폭 38 |  반복 261 / 351 | 시간 16[s] | 손실 0.73
# | 에폭 38 |  반복 281 / 351 | 시간 18[s] | 손실 0.67
# | 에폭 38 |  반복 301 / 351 | 시간 19[s] | 손실 0.67
# | 에폭 38 |  반복 321 / 351 | 시간 20[s] | 손실 0.66
# | 에폭 38 |  반복 341 / 351 | 시간 22[s] | 손실 0.66
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 671
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 426
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 14.820%
# | 에폭 39 |  반복 1 / 351 | 시간 0[s] | 손실 0.65
# | 에폭 39 |  반복 21 / 351 | 시간 1[s] | 손실 0.65
# | 에폭 39 |  반복 41 / 351 | 시간 2[s] | 손실 0.70
# | 에폭 39 |  반복 61 / 351 | 시간 3[s] | 손실 0.66
# | 에폭 39 |  반복 81 / 351 | 시간 5[s] | 손실 0.68
# | 에폭 39 |  반복 101 / 351 | 시간 6[s] | 손실 0.67
# | 에폭 39 |  반복 121 / 351 | 시간 7[s] | 손실 0.73
# | 에폭 39 |  반복 141 / 351 | 시간 9[s] | 손실 0.76
# | 에폭 39 |  반복 161 / 351 | 시간 10[s] | 손실 0.67
# | 에폭 39 |  반복 181 / 351 | 시간 11[s] | 손실 0.68
# | 에폭 39 |  반복 201 / 351 | 시간 13[s] | 손실 0.67
# | 에폭 39 |  반복 221 / 351 | 시간 14[s] | 손실 0.67
# | 에폭 39 |  반복 241 / 351 | 시간 15[s] | 손실 0.67
# | 에폭 39 |  반복 261 / 351 | 시간 16[s] | 손실 0.66
# | 에폭 39 |  반복 281 / 351 | 시간 18[s] | 손실 0.66
# | 에폭 39 |  반복 301 / 351 | 시간 19[s] | 손실 0.67
# | 에폭 39 |  반복 321 / 351 | 시간 20[s] | 손실 0.67
# | 에폭 39 |  반복 341 / 351 | 시간 22[s] | 손실 0.65
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 670
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 14.520%
# | 에폭 40 |  반복 1 / 351 | 시간 0[s] | 손실 0.67
# | 에폭 40 |  반복 21 / 351 | 시간 1[s] | 손실 0.65
# | 에폭 40 |  반복 41 / 351 | 시간 2[s] | 손실 0.65
# | 에폭 40 |  반복 61 / 351 | 시간 4[s] | 손실 0.66
# | 에폭 40 |  반복 81 / 351 | 시간 5[s] | 손실 0.67
# | 에폭 40 |  반복 101 / 351 | 시간 6[s] | 손실 0.64
# | 에폭 40 |  반복 121 / 351 | 시간 7[s] | 손실 0.64
# | 에폭 40 |  반복 141 / 351 | 시간 9[s] | 손실 0.65
# | 에폭 40 |  반복 161 / 351 | 시간 10[s] | 손실 0.66
# | 에폭 40 |  반복 181 / 351 | 시간 11[s] | 손실 0.68
# | 에폭 40 |  반복 201 / 351 | 시간 13[s] | 손실 0.67
# | 에폭 40 |  반복 221 / 351 | 시간 14[s] | 손실 0.65
# | 에폭 40 |  반복 241 / 351 | 시간 15[s] | 손실 0.66
# | 에폭 40 |  반복 261 / 351 | 시간 17[s] | 손실 0.67
# | 에폭 40 |  반복 281 / 351 | 시간 18[s] | 손실 0.63
# | 에폭 40 |  반복 301 / 351 | 시간 19[s] | 손실 0.63
# | 에폭 40 |  반복 321 / 351 | 시간 20[s] | 손실 0.64
# | 에폭 40 |  반복 341 / 351 | 시간 22[s] | 손실 0.68
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1146
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1061
# ---
# Q 830+597
# T 1427
# ☒ 1426
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 18.980%
# | 에폭 41 |  반복 1 / 351 | 시간 0[s] | 손실 0.62
# | 에폭 41 |  반복 21 / 351 | 시간 1[s] | 손실 0.69
# | 에폭 41 |  반복 41 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 41 |  반복 61 / 351 | 시간 3[s] | 손실 0.66
# | 에폭 41 |  반복 81 / 351 | 시간 5[s] | 손실 0.66
# | 에폭 41 |  반복 101 / 351 | 시간 6[s] | 손실 0.64
# | 에폭 41 |  반복 121 / 351 | 시간 7[s] | 손실 0.65
# | 에폭 41 |  반복 141 / 351 | 시간 9[s] | 손실 0.68
# | 에폭 41 |  반복 161 / 351 | 시간 10[s] | 손실 0.67
# | 에폭 41 |  반복 181 / 351 | 시간 11[s] | 손실 0.67
# | 에폭 41 |  반복 201 / 351 | 시간 13[s] | 손실 0.66
# | 에폭 41 |  반복 221 / 351 | 시간 14[s] | 손실 0.67
# | 에폭 41 |  반복 241 / 351 | 시간 15[s] | 손실 0.66
# | 에폭 41 |  반복 261 / 351 | 시간 16[s] | 손실 0.67
# | 에폭 41 |  반복 281 / 351 | 시간 18[s] | 손실 0.67
# | 에폭 41 |  반복 301 / 351 | 시간 19[s] | 손실 0.68
# | 에폭 41 |  반복 321 / 351 | 시간 20[s] | 손실 0.67
# | 에폭 41 |  반복 341 / 351 | 시간 22[s] | 손실 0.66
# Q 77+85
# T 162
# ☒ 166
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 864
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1430
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 10.860%
# | 에폭 42 |  반복 1 / 351 | 시간 0[s] | 손실 0.70
# | 에폭 42 |  반복 21 / 351 | 시간 1[s] | 손실 0.64
# | 에폭 42 |  반복 41 / 351 | 시간 2[s] | 손실 0.64
# | 에폭 42 |  반복 61 / 351 | 시간 3[s] | 손실 0.64
# | 에폭 42 |  반복 81 / 351 | 시간 5[s] | 손실 0.67
# | 에폭 42 |  반복 101 / 351 | 시간 6[s] | 손실 0.65
# | 에폭 42 |  반복 121 / 351 | 시간 7[s] | 손실 0.65
# | 에폭 42 |  반복 141 / 351 | 시간 9[s] | 손실 0.66
# | 에폭 42 |  반복 161 / 351 | 시간 10[s] | 손실 0.67
# | 에폭 42 |  반복 181 / 351 | 시간 11[s] | 손실 0.66
# | 에폭 42 |  반복 201 / 351 | 시간 13[s] | 손실 0.65
# | 에폭 42 |  반복 221 / 351 | 시간 14[s] | 손실 0.66
# | 에폭 42 |  반복 241 / 351 | 시간 15[s] | 손실 0.65
# | 에폭 42 |  반복 261 / 351 | 시간 17[s] | 손실 0.67
# | 에폭 42 |  반복 281 / 351 | 시간 18[s] | 손실 0.67
# | 에폭 42 |  반복 301 / 351 | 시간 19[s] | 손실 0.63
# | 에폭 42 |  반복 321 / 351 | 시간 20[s] | 손실 0.67
# | 에폭 42 |  반복 341 / 351 | 시간 22[s] | 손실 0.67
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 854
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1415
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 15.660%
# | 에폭 43 |  반복 1 / 351 | 시간 0[s] | 손실 0.61
# | 에폭 43 |  반복 21 / 351 | 시간 1[s] | 손실 0.64
# | 에폭 43 |  반복 41 / 351 | 시간 2[s] | 손실 0.64
# | 에폭 43 |  반복 61 / 351 | 시간 4[s] | 손실 0.65
# | 에폭 43 |  반복 81 / 351 | 시간 5[s] | 손실 0.65
# | 에폭 43 |  반복 101 / 351 | 시간 6[s] | 손실 0.62
# | 에폭 43 |  반복 121 / 351 | 시간 7[s] | 손실 0.64
# | 에폭 43 |  반복 141 / 351 | 시간 9[s] | 손실 0.65
# | 에폭 43 |  반복 161 / 351 | 시간 10[s] | 손실 0.65
# | 에폭 43 |  반복 181 / 351 | 시간 11[s] | 손실 0.63
# | 에폭 43 |  반복 201 / 351 | 시간 13[s] | 손실 0.63
# | 에폭 43 |  반복 221 / 351 | 시간 14[s] | 손실 0.66
# | 에폭 43 |  반복 241 / 351 | 시간 15[s] | 손실 0.62
# | 에폭 43 |  반복 261 / 351 | 시간 17[s] | 손실 0.64
# | 에폭 43 |  반복 281 / 351 | 시간 18[s] | 손실 0.63
# | 에폭 43 |  반복 301 / 351 | 시간 19[s] | 손실 0.63
# | 에폭 43 |  반복 321 / 351 | 시간 21[s] | 손실 0.65
# | 에폭 43 |  반복 341 / 351 | 시간 22[s] | 손실 0.68
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1151
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1426
# ---
# Q 26+838
# T 864
# ☒ 866
# ---
# Q 143+93
# T 236
# ☒ 246
# ---
# 검증 정확도 14.140%
# | 에폭 44 |  반복 1 / 351 | 시간 0[s] | 손실 0.67
# | 에폭 44 |  반복 21 / 351 | 시간 1[s] | 손실 0.66
# | 에폭 44 |  반복 41 / 351 | 시간 2[s] | 손실 0.64
# | 에폭 44 |  반복 61 / 351 | 시간 4[s] | 손실 0.67
# | 에폭 44 |  반복 81 / 351 | 시간 5[s] | 손실 0.62
# | 에폭 44 |  반복 101 / 351 | 시간 6[s] | 손실 0.62
# | 에폭 44 |  반복 121 / 351 | 시간 7[s] | 손실 0.62
# | 에폭 44 |  반복 141 / 351 | 시간 9[s] | 손실 0.63
# | 에폭 44 |  반복 161 / 351 | 시간 10[s] | 손실 0.64
# | 에폭 44 |  반복 181 / 351 | 시간 11[s] | 손실 0.62
# | 에폭 44 |  반복 201 / 351 | 시간 13[s] | 손실 0.65
# | 에폭 44 |  반복 221 / 351 | 시간 14[s] | 손실 0.63
# | 에폭 44 |  반복 241 / 351 | 시간 15[s] | 손실 0.61
# | 에폭 44 |  반복 261 / 351 | 시간 16[s] | 손실 0.63
# | 에폭 44 |  반복 281 / 351 | 시간 18[s] | 손실 0.64
# | 에폭 44 |  반복 301 / 351 | 시간 19[s] | 손실 0.63
# | 에폭 44 |  반복 321 / 351 | 시간 20[s] | 손실 0.63
# | 에폭 44 |  반복 341 / 351 | 시간 22[s] | 손실 0.64
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1421
# ---
# Q 26+838
# T 864
# ☒ 863
# ---
# Q 143+93
# T 236
# ☒ 231
# ---
# 검증 정확도 15.560%
# | 에폭 45 |  반복 1 / 351 | 시간 0[s] | 손실 0.64
# | 에폭 45 |  반복 21 / 351 | 시간 1[s] | 손실 0.63
# | 에폭 45 |  반복 41 / 351 | 시간 2[s] | 손실 0.65
# | 에폭 45 |  반복 61 / 351 | 시간 3[s] | 손실 0.64
# | 에폭 45 |  반복 81 / 351 | 시간 5[s] | 손실 0.61
# | 에폭 45 |  반복 101 / 351 | 시간 6[s] | 손실 0.63
# | 에폭 45 |  반복 121 / 351 | 시간 7[s] | 손실 0.63
# | 에폭 45 |  반복 141 / 351 | 시간 9[s] | 손실 0.61
# | 에폭 45 |  반복 161 / 351 | 시간 10[s] | 손실 0.63
# | 에폭 45 |  반복 181 / 351 | 시간 11[s] | 손실 0.63
# | 에폭 45 |  반복 201 / 351 | 시간 13[s] | 손실 0.63
# | 에폭 45 |  반복 221 / 351 | 시간 14[s] | 손실 0.64
# | 에폭 45 |  반복 241 / 351 | 시간 15[s] | 손실 0.63
# | 에폭 45 |  반복 261 / 351 | 시간 17[s] | 손실 0.62
# | 에폭 45 |  반복 281 / 351 | 시간 18[s] | 손실 0.64
# | 에폭 45 |  반복 301 / 351 | 시간 19[s] | 손실 0.64
# | 에폭 45 |  반복 321 / 351 | 시간 21[s] | 손실 0.61
# | 에폭 45 |  반복 341 / 351 | 시간 22[s] | 손실 0.61
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 670
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1068
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 15.060%
# | 에폭 46 |  반복 1 / 351 | 시간 0[s] | 손실 0.64
# | 에폭 46 |  반복 21 / 351 | 시간 1[s] | 손실 0.63
# | 에폭 46 |  반복 41 / 351 | 시간 2[s] | 손실 0.60
# | 에폭 46 |  반복 61 / 351 | 시간 4[s] | 손실 0.60
# | 에폭 46 |  반복 81 / 351 | 시간 5[s] | 손실 0.60
# | 에폭 46 |  반복 101 / 351 | 시간 6[s] | 손실 0.63
# | 에폭 46 |  반복 121 / 351 | 시간 8[s] | 손실 0.60
# | 에폭 46 |  반복 141 / 351 | 시간 9[s] | 손실 0.60
# | 에폭 46 |  반복 161 / 351 | 시간 10[s] | 손실 0.60
# | 에폭 46 |  반복 181 / 351 | 시간 12[s] | 손실 0.62
# | 에폭 46 |  반복 201 / 351 | 시간 13[s] | 손실 0.61
# | 에폭 46 |  반복 221 / 351 | 시간 14[s] | 손실 0.64
# | 에폭 46 |  반복 241 / 351 | 시간 16[s] | 손실 0.62
# | 에폭 46 |  반복 261 / 351 | 시간 17[s] | 손실 0.63
# | 에폭 46 |  반복 281 / 351 | 시간 18[s] | 손실 0.61
# | 에폭 46 |  반복 301 / 351 | 시간 20[s] | 손실 0.62
# | 에폭 46 |  반복 321 / 351 | 시간 21[s] | 손실 0.62
# | 에폭 46 |  반복 341 / 351 | 시간 22[s] | 손실 0.60
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1415
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 18.140%
# | 에폭 47 |  반복 1 / 351 | 시간 0[s] | 손실 0.59
# | 에폭 47 |  반복 21 / 351 | 시간 1[s] | 손실 0.60
# | 에폭 47 |  반복 41 / 351 | 시간 2[s] | 손실 0.60
# | 에폭 47 |  반복 61 / 351 | 시간 4[s] | 손실 0.64
# | 에폭 47 |  반복 81 / 351 | 시간 5[s] | 손실 0.60
# | 에폭 47 |  반복 101 / 351 | 시간 6[s] | 손실 0.61
# | 에폭 47 |  반복 121 / 351 | 시간 8[s] | 손실 0.63
# | 에폭 47 |  반복 141 / 351 | 시간 9[s] | 손실 0.61
# | 에폭 47 |  반복 161 / 351 | 시간 10[s] | 손실 0.59
# | 에폭 47 |  반복 181 / 351 | 시간 12[s] | 손실 0.63
# | 에폭 47 |  반복 201 / 351 | 시간 13[s] | 손실 0.61
# | 에폭 47 |  반복 221 / 351 | 시간 14[s] | 손실 0.64
# | 에폭 47 |  반복 241 / 351 | 시간 16[s] | 손실 0.61
# | 에폭 47 |  반복 261 / 351 | 시간 17[s] | 손실 0.63
# | 에폭 47 |  반복 281 / 351 | 시간 18[s] | 손실 0.60
# | 에폭 47 |  반복 301 / 351 | 시간 20[s] | 손실 0.58
# | 에폭 47 |  반복 321 / 351 | 시간 21[s] | 손실 0.64
# | 에폭 47 |  반복 341 / 351 | 시간 22[s] | 손실 0.62
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1131
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 16.760%
# | 에폭 48 |  반복 1 / 351 | 시간 0[s] | 손실 0.60
# | 에폭 48 |  반복 21 / 351 | 시간 1[s] | 손실 0.65
# | 에폭 48 |  반복 41 / 351 | 시간 2[s] | 손실 0.61
# | 에폭 48 |  반복 61 / 351 | 시간 3[s] | 손실 0.65
# | 에폭 48 |  반복 81 / 351 | 시간 5[s] | 손실 0.62
# | 에폭 48 |  반복 101 / 351 | 시간 6[s] | 손실 0.62
# | 에폭 48 |  반복 121 / 351 | 시간 7[s] | 손실 0.62
# | 에폭 48 |  반복 141 / 351 | 시간 9[s] | 손실 0.61
# | 에폭 48 |  반복 161 / 351 | 시간 10[s] | 손실 0.61
# | 에폭 48 |  반복 181 / 351 | 시간 11[s] | 손실 0.59
# | 에폭 48 |  반복 201 / 351 | 시간 13[s] | 손실 0.58
# | 에폭 48 |  반복 221 / 351 | 시간 14[s] | 손실 0.58
# | 에폭 48 |  반복 241 / 351 | 시간 15[s] | 손실 0.59
# | 에폭 48 |  반복 261 / 351 | 시간 16[s] | 손실 0.59
# | 에폭 48 |  반복 281 / 351 | 시간 18[s] | 손실 0.59
# | 에폭 48 |  반복 301 / 351 | 시간 19[s] | 손실 0.60
# | 에폭 48 |  반복 321 / 351 | 시간 20[s] | 손실 0.61
# | 에폭 48 |  반복 341 / 351 | 시간 22[s] | 손실 0.62
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 671
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1062
# ---
# Q 830+597
# T 1427
# ☒ 1435
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 240
# ---
# 검증 정확도 8.360%
# | 에폭 49 |  반복 1 / 351 | 시간 0[s] | 손실 0.67
# | 에폭 49 |  반복 21 / 351 | 시간 1[s] | 손실 0.60
# | 에폭 49 |  반복 41 / 351 | 시간 2[s] | 손실 0.60
# | 에폭 49 |  반복 61 / 351 | 시간 3[s] | 손실 0.63
# | 에폭 49 |  반복 81 / 351 | 시간 5[s] | 손실 0.59
# | 에폭 49 |  반복 101 / 351 | 시간 6[s] | 손실 0.57
# | 에폭 49 |  반복 121 / 351 | 시간 7[s] | 손실 0.62
# | 에폭 49 |  반복 141 / 351 | 시간 9[s] | 손실 0.60
# | 에폭 49 |  반복 161 / 351 | 시간 10[s] | 손실 0.63
# | 에폭 49 |  반복 181 / 351 | 시간 11[s] | 손실 0.58
# | 에폭 49 |  반복 201 / 351 | 시간 13[s] | 손실 0.59
# | 에폭 49 |  반복 221 / 351 | 시간 14[s] | 손실 0.59
# | 에폭 49 |  반복 241 / 351 | 시간 15[s] | 손실 0.62
# | 에폭 49 |  반복 261 / 351 | 시간 16[s] | 손실 0.60
# | 에폭 49 |  반복 281 / 351 | 시간 18[s] | 손실 0.61
# | 에폭 49 |  반복 301 / 351 | 시간 19[s] | 손실 0.62
# | 에폭 49 |  반복 321 / 351 | 시간 20[s] | 손실 0.62
# | 에폭 49 |  반복 341 / 351 | 시간 22[s] | 손실 0.61
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☒ 860
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 21.720%
# | 에폭 50 |  반복 1 / 351 | 시간 0[s] | 손실 0.58
# | 에폭 50 |  반복 21 / 351 | 시간 1[s] | 손실 0.60
# | 에폭 50 |  반복 41 / 351 | 시간 2[s] | 손실 0.58
# | 에폭 50 |  반복 61 / 351 | 시간 4[s] | 손실 0.57
# | 에폭 50 |  반복 81 / 351 | 시간 5[s] | 손실 0.58
# | 에폭 50 |  반복 101 / 351 | 시간 6[s] | 손실 0.60
# | 에폭 50 |  반복 121 / 351 | 시간 8[s] | 손실 0.61
# | 에폭 50 |  반복 141 / 351 | 시간 9[s] | 손실 0.59
# | 에폭 50 |  반복 161 / 351 | 시간 10[s] | 손실 0.59
# | 에폭 50 |  반복 181 / 351 | 시간 12[s] | 손실 0.60
# | 에폭 50 |  반복 201 / 351 | 시간 13[s] | 손실 0.62
# | 에폭 50 |  반복 221 / 351 | 시간 14[s] | 손실 0.60
# | 에폭 50 |  반복 241 / 351 | 시간 16[s] | 손실 0.60
# | 에폭 50 |  반복 261 / 351 | 시간 17[s] | 손실 0.58
# | 에폭 50 |  반복 281 / 351 | 시간 18[s] | 손실 0.58
# | 에폭 50 |  반복 301 / 351 | 시간 20[s] | 손실 0.59
# | 에폭 50 |  반복 321 / 351 | 시간 21[s] | 손실 0.62
# | 에폭 50 |  반복 341 / 351 | 시간 22[s] | 손실 0.60
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1063
# ---
# Q 830+597
# T 1427
# ☒ 1435
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 15.580%

# %%
# 정답률 추이 그래프
import matplotlib.pyplot as plt
plt.figure(figsize=(12,9))
plt.plot(acc_list,marker='o')

# Strings
xlab = 'epochs'
ylab = 'accuracy'

# Add axis labels
plt.xlabel(xlab,size =20)
plt.ylabel(ylab,size=20)

plt.show()
